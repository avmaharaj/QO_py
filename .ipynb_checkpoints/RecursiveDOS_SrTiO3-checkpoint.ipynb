# %%
from solver import RecursiveSolver
from hamiltonian import T2g_SpinOrbit_Model
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
mymodel = T2g_SpinOrbit_Model( spin_orbit = 0.0, theta = 0.0, phi = 1.1, mu = -4.35, delta = 0.001, t2 =0.2)
solver = RecursiveSolver(mymodel, system_size = 2048, min_invfield = 10.0, max_invfield = 10000.0,num_steps = 5000)
out = solver.run()
# Out:
# Completed iteration 100 of 5000
# Completed iteration 200 of 5000
# Completed iteration 300 of 5000
# Completed iteration 400 of 5000
# Completed iteration 500 of 5000
# Completed iteration 600 of 5000
# Completed iteration 700 of 5000
# Completed iteration 800 of 5000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-a9edef876409> in <module>()
#       1 mymodel = T2g_SpinOrbit_Model( spin_orbit = 0.0, theta = 0.0, phi = 1.1, mu = -4.35, delta = 0.001, t2 =0.2)
#       2 solver = RecursiveSolver(mymodel, system_size = 1024, min_invfield = 10.0, max_invfield = 10000.0,num_steps = 5000)
# ----> 3 out = solver.run()
#
# /Users/amaharaj/Documents/Research/SrTiO/python_code/solver.py in run(self)
#      96             dos = 0.0 + 0.0*1j
#      97             self.bfield = 1.0*np.pi/(lower_inv_field + b * dfield)
# ---> 98             dos = self._get_dos()
# ...

# %%
plt.plot(out[:,0].real,out[:,1].real,'-o')

# %%
b = np.fft.fft(out[:,1].real)
n = out[:,0].size
invbstep = out[1,0]-out[0,0]
freq = np.fft.fftfreq(n, d=invbstep)
plt.plot(freq,np.abs(b),'o-')
plt.xlim((0.001,0.1))
plt.ylim((0,400))
# Out:
# (0, 400)
